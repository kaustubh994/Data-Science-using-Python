# %% [markdown]
# # Pandas Exercise: Basic Stats (Wind Statistics)

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/guipsamora/pandas_exercises/blob/master/Stats/Wind_Stats/wind.data)

# %%
p=pd.read_csv("C://Users//kaust//Desktop//Datasets//dataset//wind.csv")

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data=p

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# 5     61   1   6  13.21   8.12   9.96   6.67   5.37   4.50  10.67   4.42
# 6     61   1   7  13.50  14.29   9.50   4.96  12.29   8.33   9.17   9.29
# 7     61   1   8  10.96   9.75   7.62   5.91   9.62   7.29  14.29   7.62
# 8     61   1   9  12.58  10.83  10.00   4.75  10.37   6.79   8.04  10.13
# 9     61   1  10  13.37  11.12  19.50   8.33   9.71   6.54  11.42   7.79
# 10    61   1  11  10.58   9.87   8.42   2.79   8.71   7.25   7.54   8.33
# 11    61   1  12  19.75  12.08  18.50  10.54  10.29   9.46  15.54  11.50
# ...

# %%
data.dtypes
# Out:
# Yr       int64
# Mo       int64
# Dy       int64
# RPT    float64
# VAL    float64
# ROS    float64
# KIL    float64
# SHA    float64
# BIR    float64
# DUB    float64
# CLA    float64
# MUL    float64
# CLO    float64
# BEL    float64
# MAL    float64
# dtype: object

# %%
data["datetime"]=pd.to_datetime((data.Yr*10000+data.Mo*100+data.Dy).apply(str),format='%y%m%d')
data.drop(columns=['Yr','Mo','Dy'],axis=1,inplace=True)
data
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# 5     13.21   8.12   9.96   6.67   5.37   4.50  10.67   4.42   7.17   7.50
# 6     13.50  14.29   9.50   4.96  12.29   8.33   9.17   9.29   7.58   7.96
# 7     10.96   9.75   7.62   5.91   9.62   7.29  14.29   7.62   9.25  10.46
# 8     12.58  10.83  10.00   4.75  10.37   6.79   8.04  10.13   7.79   9.08
# 9     13.37  11.12  19.50   8.33   9.71   6.54  11.42   7.79   8.54   9.00
# 10    10.58   9.87   8.42   2.79   8.71   7.25   7.54   8.33   5.71   8.67
# ...

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
data["datetime"]=data["datetime"].map(lambda x: x.replace(year=2012))

# %%
data
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# 5     13.21   8.12   9.96   6.67   5.37   4.50  10.67   4.42   7.17   7.50
# 6     13.50  14.29   9.50   4.96  12.29   8.33   9.17   9.29   7.58   7.96
# 7     10.96   9.75   7.62   5.91   9.62   7.29  14.29   7.62   9.25  10.46
# 8     12.58  10.83  10.00   4.75  10.37   6.79   8.04  10.13   7.79   9.08
# 9     13.37  11.12  19.50   8.33   9.71   6.54  11.42   7.79   8.54   9.00
# 10    10.58   9.87   8.42   2.79   8.71   7.25   7.54   8.33   5.71   8.67
# ...

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.dtypes
# Out:
# RPT                float64
# VAL                float64
# ROS                float64
# KIL                float64
# SHA                float64
# BIR                float64
# DUB                float64
# CLA                float64
# MUL                float64
# CLO                float64
# BEL                float64
# MAL                float64
# datetime    datetime64[ns]
# dtype: object

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isnull().sum()
# Out:
# RPT         6
# VAL         3
# ROS         2
# KIL         5
# SHA         2
# BIR         0
# DUB         3
# CLA         2
# MUL         3
# CLO         1
# BEL         0
# MAL         4
# datetime    0
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.count(axis=1).sum()
# Out:
# 85431

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data[["RPT","VAL","ROS","KIL","SHA","BIR","DUB","CLA","MUL","CLO","BEL","MAL"]].stack().mean()
# Out:
# 10.22788376428219

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats=pd.DataFrame(data)

# %%
loc_stats[["RPT","VAL","ROS","KIL","SHA","BIR","DUB","CLA","MUL","CLO","BEL","MAL"]].max()
# Out:
# RPT    35.80
# VAL    33.37
# ROS    33.84
# KIL    28.46
# SHA    37.54
# BIR    26.16
# DUB    30.37
# CLA    31.08
# MUL    25.88
# CLO    28.21
# BEL    42.38
# MAL    42.54
# dtype: float64

# %%
loc_stats[["RPT","VAL","ROS","KIL","SHA","BIR","DUB","CLA","MUL","CLO","BEL","MAL"]].min()
# Out:
# RPT    0.67
# VAL    0.21
# ROS    1.50
# KIL    0.00
# SHA    0.13
# BIR    0.00
# DUB    0.00
# CLA    0.00
# MUL    0.00
# CLO    0.04
# BEL    0.13
# MAL    0.67
# dtype: float64

# %%
loc_stats[["RPT","VAL","ROS","KIL","SHA","BIR","DUB","CLA","MUL","CLO","BEL","MAL"]].mean()
# Out:
# RPT    12.362987
# VAL    10.644314
# ROS    11.660526
# KIL     6.306468
# SHA    10.455834
# BIR     7.092254
# DUB     9.797343
# CLA     8.495053
# MUL     8.493590
# CLO     8.707332
# BEL    13.121007
# MAL    15.599079
# dtype: float64

# %%
loc_stats.std()
# Out:
# RPT    5.618413
# VAL    5.267356
# ROS    5.008450
# KIL    3.605811
# SHA    4.936125
# BIR    3.968683
# DUB    4.977555
# CLA    4.499449
# MUL    4.166872
# CLO    4.503954
# BEL    5.835037
# MAL    6.699794
# dtype: float64

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats=pd.DataFrame(data)

# %%
day_stats.max(axis=1)
# Out:
# 0       18.50
# 1       17.54
# 2       18.50
# 3       11.75
# 4       13.33
# 5       13.21
# 6       14.29
# 7       16.62
# 8       15.37
# 9       19.50
# 10      20.71
# 11      19.75
# 12       9.92
# 13       9.04
# 14      12.04
# 15      16.42
# 16      17.75
# 17      20.79
# 18       7.83
# 19      11.83
# 20      14.33
# 21      10.88
# 22      20.58
# 23      25.84
# 24      17.50
# 25      25.25
# 26      27.63
# 27      20.30
# 28      27.71
# 29      19.25
#         ...
# 6544    19.95
# 6545    25.75
# 6546    17.96
# 6547    22.75
# 6548    34.46
# 6549    34.59
# 6550    17.33
# 6551    18.71
# 6552    26.08
# 6553    22.83
# 6554    23.13
# 6555    24.04
# 6556    19.75
# 6557    17.16
# 6558    18.08
# 6559     9.87
# 6560    19.79
# 6561    18.25
# 6562    12.38
# 6563    20.30
# 6564    13.08
# 6565    22.21
# 6566    31.71
# 6567    13.96
# 6568    13.83
# 6569    40.08
# 6570    41.46
# 6571    29.58
# 6572    28.79
# 6573    27.29
# ...

# %%
day_stats.min(axis=1)
# Out:
# 0        9.29
# 1        6.50
# 2        6.17
# 3        1.79
# 4        6.17
# 5        4.42
# 6        4.96
# 7        5.91
# 8        4.75
# 9        6.54
# 10       2.79
# 11       9.46
# 12       0.58
# 13       0.50
# 14       2.37
# 15       4.71
# 16       8.71
# 17       8.79
# 18       1.04
# 19       1.58
# 20       6.13
# 21       2.17
# 22       9.96
# 23      14.83
# 24       6.04
# 25      14.25
# 26      16.13
# 27       8.87
# 28      17.54
# 29       7.92
#         ...
# 6544     5.13
# 6545    11.58
# 6546     1.71
# 6547     8.50
# 6548    16.04
# 6549    18.16
# 6550     3.37
# 6551     6.04
# 6552    13.00
# 6553    11.63
# 6554     8.29
# 6555     8.33
# 6556     3.37
# 6557     4.00
# 6558     2.46
# 6559     0.54
# 6560     1.00
# 6561     2.33
# 6562     0.42
# 6563     3.83
# 6564     2.46
# 6565     9.50
# 6566     4.79
# 6567     0.75
# 6568     1.96
# 6569     8.08
# 6570     5.00
# 6571     8.71
# 6572     9.13
# 6573     9.59
# ...

# %%
day_stats.mean(axis=1)
# Out:
# 0       13.018182
# 1       11.336364
# 2       11.641818
# 3        6.619167
# 4       10.630000
# 5        8.240000
# 6       10.385000
# 7       10.487500
# 8        9.897500
# 9       10.477500
# 10       9.625000
# 11      13.524167
# 12       4.277500
# 13       3.975833
# 14       6.695000
# 15      10.164167
# 16      13.621667
# 17      15.348182
# 18       4.111667
# 19       5.980000
# 20       9.302500
# 21       7.582500
# 22      14.034167
# 23      20.000833
# 24      10.965000
# 25      18.324167
# 26      19.845833
# 27      13.690833
# 28      22.024545
# 29      12.490833
#           ...
# 6544    10.975833
# 6545    18.025000
# 6546    10.293333
# 6547    15.770833
# 6548    23.283333
# 6549    22.910000
# 6550     9.108333
# 6551    12.292500
# 6552    17.910000
# 6553    16.812500
# 6554    13.400833
# 6555    16.229167
# 6556     9.551667
# 6557     9.205833
# 6558     9.245000
# 6559     4.072500
# 6560     8.820000
# 6561     8.685000
# 6562     5.025833
# ...

# %%
day_stats.std(axis=1)
# Out:
# 0       2.808875
# 1       3.188994
# 2       3.681912
# 3       3.198126
# 4       2.445356
# 5       2.998063
# 6       3.072114
# 7       3.547237
# 8       2.905954
# 9       3.442610
# 10      4.805082
# 11      3.375046
# 12      2.916349
# 13      2.788833
# 14      3.276740
# 15      3.521277
# 16      2.874739
# 17      4.128786
# 18      2.171325
# 19      3.017220
# 20      2.546210
# 21      2.485328
# 22      3.208592
# 23      4.178121
# 24      3.215017
# 25      3.639547
# 26      3.723692
# 27      3.444483
# 28      2.744060
# 29      3.513766
#           ...
# 6544    4.003148
# 6545    3.829953
# 6546    4.574457
# 6547    4.054258
# 6548    4.983313
# 6549    4.542096
# 6550    3.933222
# 6551    3.774715
# 6552    4.651189
# 6553    3.177189
# 6554    4.390385
# 6555    4.573168
# 6556    5.145011
# 6557    4.513284
# 6558    5.101314
# 6559    3.193451
# 6560    5.912305
# 6561    4.289142
# 6562    3.734645
# 6563    4.495655
# 6564    3.237337
# ...

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
import datetime

# %%
data["month"]=pd.DatetimeIndex(data["datetime"]).month

# %%
(data[data["month"]==1]).mean()
# Out:
# RPT      14.847325
# VAL      12.914560
# ROS      13.299624
# KIL       7.199498
# SHA      11.667734
# BIR       8.054839
# DUB      11.819355
# CLA       9.512047
# MUL       9.543208
# CLO      10.053566
# BEL      14.550520
# MAL      18.028763
# month     1.000000
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
data["year"]=pd.DatetimeIndex(data["datetime"]).year

# %%
data.datetime=pd.to_datetime(data.datetime)

# %%
d1=data.resample('AS', on="datetime").sum()

# %%
d1
# Out:
#                 RPT       VAL       ROS       KIL       SHA       BIR  \
# datetime
# 2012-01-01  81200.1  69943.79  76632.98  41427.19  68715.74  46624.48
#
#                  DUB       CLA       MUL       CLO      BEL        MAL  month  \
# datetime
# 2012-01-01  64378.34  55829.49  55811.38  57233.29  86257.5  102485.95  42884
#
#                 year
# datetime
# 2012-01-01  13226888

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
d2=data.resample('M', on="datetime").sum()

# %%
d2
# Out:
#                 RPT      VAL      ROS      KIL      SHA      BIR      DUB  \
# datetime
# 2012-01-31  8269.96  7193.41  7421.19  4017.32  6487.26  4494.60  6595.20
# 2012-02-29  6965.14  6152.45  6529.72  3512.86  5868.30  3878.00  5692.66
# 2012-03-31  7316.23  6420.26  7057.65  4047.11  6447.42  4441.35  6311.08
# 2012-04-30  6780.05  5632.07  6590.60  3724.94  5765.94  4018.35  5519.51
# 2012-05-31  6542.01  5651.11  6445.12  3513.27  5705.16  3873.67  4900.34
# 2012-06-30  5633.26  4832.84  5595.11  3052.23  5146.16  3461.45  4325.16
# 2012-07-31  5575.54  4663.64  5217.10  3022.65  5190.87  3332.57  4368.83
# 2012-08-31  5688.87  4695.65  5576.34  2941.04  4967.07  3287.21  4336.95
# 2012-09-30  6187.60  5379.76  5797.96  3026.58  5273.81  3545.76  4649.25
# 2012-10-31  7051.96  6143.96  6391.30  3384.39  5887.04  3995.23  5238.38
# 2012-11-30  7128.39  6285.33  6638.44  3373.71  5670.61  3852.54  5829.21
# ...

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
d3=data.resample('W', on="datetime").sum()

# %%
d3
# Out:
#                 RPT      VAL      ROS     KIL      SHA      BIR      DUB  \
# datetime
# 2012-01-01   262.98   201.61   232.77  123.22   180.41   138.21   228.19
# 2012-01-08  1668.77  1397.42  1538.54  778.94  1260.08   877.49  1384.43
# 2012-01-15  1965.49  1709.91  1760.90  948.56  1536.48  1042.75  1519.01
# 2012-01-22  1938.54  1745.16  1689.25  930.07  1579.74  1106.10  1533.47
# 2012-01-29  1852.04  1622.85  1637.44  937.01  1461.91  1010.46  1433.97
# 2012-02-05  1810.38  1623.97  1688.28  913.68  1490.01  1010.32  1535.21
# 2012-02-12  1707.79  1464.05  1522.09  827.77  1411.36   893.35  1380.12
# 2012-02-19  1814.64  1592.85  1681.38  880.10  1506.06   994.37  1419.99
# 2012-02-26  1659.35  1478.96  1676.58  899.67  1440.76   974.08  1415.64
# 2012-03-04  1422.88  1280.95  1412.55  742.30  1215.44   816.45  1191.43
# 2012-03-11  1761.04  1546.17  1682.30  939.01  1484.86  1037.78  1363.06
# 2012-03-18  1652.16  1441.48  1624.15  935.23  1476.66  1028.11  1489.57
# ...

# %% [markdown]
# ### Step 15. Calculate the mean windspeed for each month in the dataset.
# #### Treat January 1961 and January 1962 as *different* months.
# #### (hint: first find a  way to create an identifier unique for each month.)

# %%
d4=data.resample('M', on="datetime").mean()

# %%
d4.mean(axis=1)
# Out:
# datetime
# 2012-01-31    153.892217
# 2012-02-29    153.506637
# 2012-03-31    153.611126
# 2012-04-30    152.930639
# 2012-05-31    152.443821
# 2012-06-30    151.840156
# 2012-07-31    151.560057
# 2012-08-31    151.515644
# 2012-09-30    152.446264
# 2012-10-31    153.361766
# 2012-11-30    153.766845
# 2012-12-31    154.514114
# Freq: M, dtype: float64

# %% [markdown]
# ### Step 16. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
a1=data.resample('W', on="datetime").min()

# %%
a1
# Out:
#              RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL  \
# datetime
# 2012-01-01  3.71  0.79  4.71  0.17  1.42  1.00  4.63  0.75  1.54  1.08  4.21
# 2012-01-08  2.62  0.54  3.54  0.37  0.42  0.13  2.50  0.00  0.54  0.13  0.58
# 2012-01-15  2.00  1.08  4.38  0.17  2.29  0.42  1.58  0.37  0.50  1.21  1.71
# 2012-01-22  1.63  3.08  3.00  0.08  1.17  0.04  0.46  0.58  0.46  0.04  1.87
# 2012-01-29  0.67  1.75  2.75  0.67  0.92  0.25  1.13  0.42  0.29  0.46  0.13
# 2012-02-05  4.00  1.21  4.17  1.42  2.50  0.29  3.50  1.29  1.87  1.17  3.54
# 2012-02-12  2.71  0.79  3.21  0.33  1.25  0.00  1.75  0.21  0.50  0.50  2.04
# 2012-02-19  2.92  2.50  3.50  0.67  1.25  0.00  2.79  0.17  0.83  0.83  2.67
# 2012-02-26  0.67  0.63  2.37  0.58  1.50  0.21  1.08  0.58  1.08  0.75  2.13
# 2012-03-04  3.96  2.00  3.42  0.50  1.58  0.00  1.63  1.13  0.54  0.25  2.37
# 2012-03-11  2.29  1.50  3.88  1.21  3.29  0.25  1.08  1.08  0.75  1.75  2.21
# ...

# %%
a2=data.resample('W', on="datetime").max()

# %%
a2
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# datetime
#