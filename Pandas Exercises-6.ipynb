# %% [markdown]
# # Pandas Exercise: Merging (MPG Cars)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars2.csv).

# %%
c1=pd.read_csv("C://Users//kaust//Desktop//Datasets//dataset//cars1.csv")
c2=pd.read_csv("C://Users//kaust//Desktop//Datasets//dataset//cars2.csv")

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
cars1=c1
cars2=c2

# %%
cars1
# Out:
#      Unnamed: 0   mpg  cylinders  displacement horsepower  weight  \
# 0             0  18.0          8           307        130    3504
# 1             1  15.0          8           350        165    3693
# 2             2  18.0          8           318        150    3436
# 3             3  16.0          8           304        150    3433
# 4             4  17.0          8           302        140    3449
# 5             5  15.0          8           429        198    4341
# 6             6  14.0          8           454        220    4354
# 7             7  14.0          8           440        215    4312
# 8             8  14.0          8           455        225    4425
# 9             9  15.0          8           390        190    3850
# 10           10  15.0          8           383        170    3563
# 11           11  14.0          8           340        160    3609
# 12           12  15.0          8           400        150    3761
# ...

# %%
cars2
# Out:
#      Unnamed: 0   mpg  cylinders  displacement horsepower  weight  \
# 0             0  33.0          4            91         53    1795
# 1             1  20.0          6           225        100    3651
# 2             2  18.0          6           250         78    3574
# 3             3  18.5          6           250        110    3645
# 4             4  17.5          6           258         95    3193
# 5             5  29.5          4            97         71    1825
# 6             6  32.0          4            85         70    1990
# 7             7  28.0          4            97         75    2155
# 8             8  26.5          4           140         72    2565
# 9             9  20.0          4           130        102    3150
# 10           10  13.0          8           318        150    3940
# 11           11  19.0          4           120         88    3270
# 12           12  19.0          6           156        108    2930
# ...

# %% [markdown]
# ### Step 4. Ops it seems our first dataset has some unnamed blank columns, fix cars1

# %%
del cars1["Unnamed: 9"]
del cars1["Unnamed: 10"]
del cars1["Unnamed: 11"]
del cars1["Unnamed: 12"]
del cars1["Unnamed: 13"]

# %%
cars1
# Out:
#      Unnamed: 0   mpg  cylinders  displacement horsepower  weight  \
# 0             0  18.0          8           307        130    3504
# 1             1  15.0          8           350        165    3693
# 2             2  18.0          8           318        150    3436
# 3             3  16.0          8           304        150    3433
# 4             4  17.0          8           302        140    3449
# 5             5  15.0          8           429        198    4341
# 6             6  14.0          8           454        220    4354
# 7             7  14.0          8           440        215    4312
# 8             8  14.0          8           455        225    4425
# 9             9  15.0          8           390        190    3850
# 10           10  15.0          8           383        170    3563
# 11           11  14.0          8           340        160    3609
# 12           12  15.0          8           400        150    3761
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
cars1.count()
# Out:
# Unnamed: 0      198
# mpg             198
# cylinders       198
# displacement    198
# horsepower      198
# weight          198
# acceleration    198
# model           198
# origin          198
# car             198
# dtype: int64

# %%
cars2.count()
# Out:
# Unnamed: 0      200
# mpg             200
# cylinders       200
# displacement    200
# horsepower      200
# weight          200
# acceleration    200
# model           200
# origin          200
# car             200
# dtype: int64

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars=pd.DataFrame(cars1,cars2)

# %% [markdown]
# ### Step 7. Ops there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
cars["owners"]=pd.DataFrame(np.random.randint(15000,73000,size=(200,1)))

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars["owners"]
# Out:
# (0, 33.0, 4, 91, 53, 1795, 17.4, 76, 3, honda civic)                            NaN
# (1, 20.0, 6, 225, 100, 3651, 17.7, 76, 1, dodge aspen se)                       NaN
# (2, 18.0, 6, 250, 78, 3574, 21.0, 76, 1, ford granada ghia)                     NaN
# (3, 18.5, 6, 250, 110, 3645, 16.2, 76, 1, pontiac ventura sj)                   NaN
# (4, 17.5, 6, 258, 95, 3193, 17.8, 76, 1, amc pacer d/l)                         NaN
# (5, 29.5, 4, 97, 71, 1825, 12.2, 76, 2, volkswagen rabbit)                      NaN
# (6, 32.0, 4, 85, 70, 1990, 17.0, 76, 3, datsun b-210)                           NaN
# (7, 28.0, 4, 97, 75, 2155, 16.4, 76, 3, toyota corolla)                         NaN
# (8, 26.5, 4, 140, 72, 2565, 13.6, 76, 1, ford pinto)                            NaN
# (9, 20.0, 4, 130, 102, 3150, 15.7, 76, 2, volvo 245)                            NaN
# (10, 13.0, 8, 318, 150, 3940, 13.2, 76, 1, plymouth volare premier v8)          NaN
# ...
